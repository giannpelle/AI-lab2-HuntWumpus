# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_AStar:AStarPlayer --horizon 50 data/world10.json
# Out:
# World details:
#   Size: (4, 4)
#   Pits: [(2, 2), (1, 3), (2, 3), (2, 3)]
#   Wumpus: [(2, 2)]
#   Gold: [(3, 3)]
#   Exits: [(3, 3)]
#   Blocks: []
#
# ************************* [ A* search with heuristic_func_smart_manhattan ] *************************
# visited nodes: 11 nodes (minimum possible is 11)
#
# actions required to solve the problem: 11
#
# Action sequence:
# ['LEFT', 'LEFT', 'MOVE', 'LEFT', 'MOVE', 'MOVE', 'LEFT', 'MOVE', 'MOVE', 'GRAB', 'CLIMB']
#
# total reward for the found solution: 989
# ********************************************************************************************************
#
# ┌───┬───┬───┬───┐
# │   │  P│  P│ G │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │W P│   │
# │   │ @^│   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 0: agent Hunter_6e0145df executing LEFT -> reward -1
# ┌───┬───┬───┬───┐
# │   │  P│  P│ G │
# ...

# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_AStar:AStarPlayer --horizon 50 examples_wumpus-world.json
# Out:
# World details:
#   Size: (5, 5)
#   Pits: [(1, 1), (1, 2), (3, 3), (3, 4), (4, 3)]
#   Wumpus: [(1, 0)]
#   Gold: [(3, 0)]
#   Exits: [(4, 4)]
#   Blocks: []
# 0,0,N,8,0,0
# 0,1,N,7,0,0
# 0,2,N,6,0,0
# 0,3,N,5,0,0
# 0,4,N,4,0,0
# 1,0,N,7,0,0
# 1,1,N,6,0,0
# 1,2,N,5,0,0
# 1,3,N,4,0,0
# 1,4,N,3,0,0
# 2,0,N,6,0,0
# 2,1,N,5,0,0
# 2,2,N,4,0,0
# 2,3,N,3,0,0
# 2,4,N,2,0,0
# 3,0,N,5,0,0
# 3,1,N,4,0,0
# 3,2,N,3,0,0
# 3,3,N,2,0,0
# 3,4,N,1,0,0
# 4,0,N,4,0,0
# 4,1,N,3,0,0
# 4,2,N,2,0,0
# 4,3,N,1,0,0
# 4,4,N,0,0,0
# 0,0,E,8,0,0
# 0,1,E,7,0,0
# 0,2,E,6,0,0
# 0,3,E,5,0,0
# 0,4,E,4,0,0
# 1,0,E,7,0,0
# 1,1,E,6,0,0
# 1,2,E,5,0,0
# 1,3,E,4,0,0
# 1,4,E,3,0,0
# 2,0,E,6,0,0
# 2,1,E,5,0,0
# 2,2,E,4,0,0
# 2,3,E,3,0,0
# 2,4,E,2,0,0
# 3,0,E,5,0,0
# 3,1,E,4,0,0
# 3,2,E,3,0,0
# 3,3,E,2,0,0
# 3,4,E,1,0,0
# 4,0,E,4,0,0
# 4,1,E,3,0,0
# 4,2,E,2,0,0
# 4,3,E,1,0,0
# 4,4,E,0,0,0
# 0,0,S,8,0,0
# 0,1,S,7,0,0
# 0,2,S,6,0,0
# 0,3,S,5,0,0
# 0,4,S,4,0,0
# 1,0,S,7,0,0
# 1,1,S,6,0,0
# 1,2,S,5,0,0
# 1,3,S,4,0,0
# 1,4,S,3,0,0
# ...
