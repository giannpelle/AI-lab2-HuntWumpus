# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_BFS:BFSPlayer
# Out:
# ---------- Playing on world: ----------
# {"size": [4, 4], "hunters": [[0, 0, "N"]], "pits": [[1, 1], [2, 2], [1, 3], [2, 3]], "wumpuses": [[2, 0]], "exits": [[0, 0]], "golds": [[3, 1]]}
# ----------------------------------------
# World details:
#   Size: (4, 4)
#   Pits: [(1, 1), (2, 2), (1, 3), (2, 3)]
#   Wumpus: [(2, 0)]
#   Gold: [(3, 1)]
#   Exits: [(0, 0)]
#   Blocks: []
#
# ************************* [ BFS search algorithm ] *************************
# visited nodes: 92 nodes (minimum possible is 16)
#
# Action sequence:
# ['RIGHT', 'MOVE', 'SHOOT', 'MOVE', 'MOVE', 'LEFT', 'MOVE', 'GRAB', 'LEFT', 'MOVE', 'LEFT', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'CLIMB']
#
# total reward for the found solution: 1025
# ********************************************************************************************************
#
# ┌───┬───┬───┬───┐
# │   │  P│  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │  P│   │ G │
# ...
