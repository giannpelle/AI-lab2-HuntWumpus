# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_UCS:UCSPlayer --horizon 50 data/world7.json
# Out:
# World details:
#   Size: (8, 8)
#   Pits: [(0, 4), (1, 1), (1, 2), (2, 1), (2, 2), (3, 1), (3, 2)]
#   Wumpus: [(2, 3)]
#   Gold: [(3, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
#
# ************************* [ UCS search algorithm ] *************************
# visited nodes: 728 nodes (minimum possible is 25)
#
# Action sequence:
# ['RIGHT', 'MOVE', 'MOVE', 'MOVE', 'MOVE', 'LEFT', 'MOVE', 'MOVE', 'MOVE', 'LEFT', 'MOVE', 'RIGHT', 'RIGHT', 'GRAB', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'MOVE', 'CLIMB']
#
# total reward for the found solution: 975
# ****************************************************************************************************
#
# ┌───┬───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# ...
