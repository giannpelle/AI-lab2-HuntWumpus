# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_AStar:AStarPlayer --horizon 50 data/world1.json
# Out:
# World details:
#   Size: (8, 8)
#   Pits: []
#   Wumpus: []
#   Gold: [(3, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
#
# ************************* [ A* search with heuristic_func_best_neighbour_smart_manhattan ] *************************
# visited nodes: 18 nodes (minimum possible is 17)
#
# actions required to solve the problem: 17
#
# Action sequence:
# ['MOVE', 'MOVE', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'GRAB', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'CLIMB']
#
# total reward for the found solution: 983
# ********************************************************************************************************
#
# ┌───┬───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ...
