# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_AStar:AStarPlayer --horizon 50 data/world8.json
# Out:
# World details:
#   Size: (8, 8)
#   Pits: [(0, 3), (1, 3), (2, 3), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1), (6, 1)]
#   Wumpus: [(3, 2)]
#   Gold: [(3, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
#
# ************************* [ A* search with heuristic_func_best_neighbour_smart_manhattan ] *************************
# visited nodes: 90 nodes (minimum possible is 21)
#
# actions required to solve the problem: 21
#
# Action sequence:
# ['MOVE', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'SHOOT', 'MOVE', 'LEFT', 'MOVE', 'GRAB', 'RIGHT', 'RIGHT', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'LEFT', 'MOVE', 'MOVE', 'CLIMB']
#
# total reward for the found solution: 970
# ********************************************************************************************************
#
# ┌───┬───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ...
