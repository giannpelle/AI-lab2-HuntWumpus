# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_AStar:AStarPlayer --horizon 50 data/world2.json
# Out:
# World details:
#   Size: (8, 8)
#   Pits: []
#   Wumpus: [(0, 1)]
#   Gold: [(3, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
#
# ************************* [ A* search with heuristic_func_best_neighbour_smart_manhattan ] *************************
# visited nodes: 34 nodes (minimum possible is 19)
#
# actions required to solve the problem: 19
#
# Action sequence:
# ['RIGHT', 'MOVE', 'MOVE', 'MOVE', 'LEFT', 'MOVE', 'MOVE', 'MOVE', 'GRAB', 'LEFT', 'MOVE', 'MOVE', 'LEFT', 'MOVE', 'MOVE', 'MOVE', 'RIGHT', 'MOVE', 'CLIMB']
#
# total reward for the found solution: 981
# ********************************************************************************************************
#
# ┌───┬───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ...
