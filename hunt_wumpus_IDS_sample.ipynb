# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_IDS:IDSPlayer
# Out:
# ---------- Playing on world: ----------
# {"size": [4, 4], "hunters": [[0, 0, "N"]], "pits": [[1, 1], [1, 2], [3, 2]], "wumpuses": [[2, 2]], "exits": [[0, 0]], "golds": [[2, 1]]}
# ----------------------------------------
# World details:
#   Size: (4, 4)
#   Pits: [(1, 1), (1, 2), (3, 2)]
#   Wumpus: [(2, 2)]
#   Gold: [(2, 1)]
#   Exits: [(0, 0)]
#   Blocks: []
# ---------------------------------------- Limit Depth (0) ----------------------------------------
# nodes explored: 1
# ---------------------------------------- Limit Depth (1) ----------------------------------------
# nodes explored: 3
# ---------------------------------------- Limit Depth (2) ----------------------------------------
# nodes explored: 6
# ---------------------------------------- Limit Depth (3) ----------------------------------------
# nodes explored: 11
# ---------------------------------------- Limit Depth (4) ----------------------------------------
# nodes explored: 18
# ...
