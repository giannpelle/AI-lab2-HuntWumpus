# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_UCS:UCSPlayer --horizon 50 data/world1.json
# Out:
# World details:
#   Size: (8, 8)
#   Pits: []
#   Wumpus: []
#   Gold: [(3, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
#
# ************************* [ UCS search algorithm ] *************************
# visited nodes: 476 nodes (minimum possible is 17)
#
# Action sequence:
# ['MOVE', 'MOVE', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'GRAB', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'CLIMB']
#
# total reward for the found solution: 983
# ****************************************************************************************************
#
# ┌───┬───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ...

# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_UCS:UCSPlayer --horizon 50 data/world2.json
# Out:
# World details:
#   Size: (8, 8)
#   Pits: []
#   Wumpus: [(0, 1)]
#   Gold: [(3, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
#
# ************************* [ UCS search algorithm ] *************************
# visited nodes: 607 nodes (minimum possible is 19)
#
# Action sequence:
# ['RIGHT', 'MOVE', 'MOVE', 'MOVE', 'LEFT', 'MOVE', 'MOVE', 'MOVE', 'LEFT', 'GRAB', 'MOVE', 'MOVE', 'LEFT', 'MOVE', 'MOVE', 'MOVE', 'RIGHT', 'MOVE', 'CLIMB']
#
# total reward for the found solution: 981
# ****************************************************************************************************
#
# ┌───┬───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# ...

# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_UCS:UCSPlayer --horizon 50 data/world3.json
# Out:
# World details:
#   Size: (8, 8)
#   Pits: [(0, 1), (1, 0)]
#   Wumpus: []
#   Gold: [(3, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
#
# ************************* [ UCS search algorithm ] *************************
# visited nodes: 1 nodes (minimum possible is 1)
#
# Action sequence:
# ['CLIMB']
#
# total reward for the found solution: -1
# ****************************************************************************************************
#
# ┌───┬───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │ G │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ...

# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_UCS:UCSPlayer --horizon 50 data/world4.json
# Out:
# World details:
#   Size: (8, 8)
#   Pits: [(0, 3), (1, 3), (2, 3), (1, 1), (2, 1), (3, 1)]
#   Wumpus: []
#   Gold: [(3, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
#
# ************************* [ UCS search algorithm ] *************************
# visited nodes: 451 nodes (minimum possible is 20)
#
# Action sequence:
# ['MOVE', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'LEFT', 'MOVE', 'RIGHT', 'GRAB', 'RIGHT', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'LEFT', 'MOVE', 'MOVE', 'CLIMB']
#
# total reward for the found solution: 980
# ****************************************************************************************************
#
# ┌───┬───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# ...

# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_UCS:UCSPlayer --horizon 50 data/world5.json
# Out:
# World details:
#   Size: (8, 8)
#   Pits: []
#   Wumpus: [(3, 3)]
#   Gold: [(3, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
#
# ************************* [ UCS search algorithm ] *************************
# visited nodes: 727 nodes (minimum possible is 18)
#
# Action sequence:
# ['MOVE', 'MOVE', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'SHOOT', 'MOVE', 'RIGHT', 'GRAB', 'MOVE', 'MOVE', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'CLIMB']
#
# total reward for the found solution: 973
# ****************************************************************************************************
#
# ┌───┬───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# ...

# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_UCS:UCSPlayer --horizon 50 data/world6.json
# Out:
# World details:
#   Size: (8, 8)
#   Pits: [(4, 6), (5, 7), (5, 5)]
#   Wumpus: [(6, 6)]
#   Gold: [(5, 6)]
#   Exits: [(0, 0)]
#   Blocks: []
#
# ************************* [ UCS search algorithm ] *************************
# visited nodes: 711 nodes (minimum possible is 36)
#
# Action sequence:
# ['MOVE', 'MOVE', 'MOVE', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'MOVE', 'MOVE', 'MOVE', 'LEFT', 'MOVE', 'SHOOT', 'MOVE', 'LEFT', 'MOVE', 'RIGHT', 'RIGHT', 'GRAB', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'MOVE', 'MOVE', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'MOVE', 'MOVE', 'MOVE', 'CLIMB']
#
# total reward for the found solution: 955
# ****************************************************************************************************
#
# ┌───┬───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │  P│   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │  P│ G │W  │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# ...

# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_UCS:UCSPlayer --horizon 50 data/world7.json
# Out:
# World details:
#   Size: (8, 8)
#   Pits: [(0, 4), (1, 1), (1, 2), (2, 1), (2, 2), (3, 1), (3, 2)]
#   Wumpus: [(2, 3)]
#   Gold: [(3, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
#
# ************************* [ UCS search algorithm ] *************************
# visited nodes: 728 nodes (minimum possible is 25)
#
# Action sequence:
# ['RIGHT', 'MOVE', 'MOVE', 'MOVE', 'MOVE', 'LEFT', 'MOVE', 'MOVE', 'MOVE', 'LEFT', 'MOVE', 'RIGHT', 'RIGHT', 'GRAB', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'MOVE', 'CLIMB']
#
# total reward for the found solution: 975
# ****************************************************************************************************
#
# ┌───┬───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# ...

# %%
# !gridrunner --world WumpusWorld --entry hunt_wumpus_UCS:UCSPlayer --horizon 50 data/world8.json
# Out:
# World details:
#   Size: (8, 8)
#   Pits: [(0, 3), (1, 3), (2, 3), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1), (6, 1)]
#   Wumpus: [(3, 2)]
#   Gold: [(3, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
#
# ************************* [ UCS search algorithm ] *************************
# visited nodes: 799 nodes (minimum possible is 21)
#
# Action sequence:
# ['MOVE', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'SHOOT', 'MOVE', 'LEFT', 'MOVE', 'RIGHT', 'GRAB', 'RIGHT', 'MOVE', 'RIGHT', 'MOVE', 'MOVE', 'MOVE', 'LEFT', 'MOVE', 'MOVE', 'CLIMB']
#
# total reward for the found solution: 970
# ****************************************************************************************************
#
# ┌───┬───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ...
